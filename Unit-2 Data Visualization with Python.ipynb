# %%
# # SEABORN
# annot=numirc
# cmap="coolwarm" colour  change
# linewidth=True give space between boxes
# cbar=False for remove bar

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
df=pd.read_csv("titanic.csv")
df

# %%
df.corr(numeric_only=True)

# %%
corr = df.corr(numeric_only=True)   # filter numeric columns here
sns.heatmap(corr)
plt.show()

# %%
corr=df.corr(numeric_only=True)
sns.heatmap(corr,annot=True)# ANNOT give value in heatmap
plt.show()

# %%
corr=df.corr(numeric_only=True)
sns.heatmap(corr,annot=True,cmap="coolwarm")
plt.show()

# %%
sns.heatmap(corr, vmin=-1, vmax=1, cmap='coolwarm')
plt.show()

# %%
corr=df.corr(numeric_only=True)
sns.heatmap(corr,annot=True,cmap="coolwarm" ,)
plt.show()

# %%
corr=df.corr(numeric_only=True)
sns.heatmap(corr,annot=True,cmap="coolwarm",linewidth=True)
plt.show()

# %%
corr=df.corr(numeric_only=True)
sns.heatmap(corr,annot=True,cmap="coolwarm",linewidth=7,linecolor="black")
plt.show()

# %%
corr=df.corr(numeric_only=True)
sns.heatmap(corr,annot=True,cmap="coolwarm",cbar=False)
plt.show()

# %%
sns.boxplot(x="pclass",y="fare",data=df)# x always category and y for numeric
plt.show()

# %%
sns.boxplot(df,x="pclass",y="fare",hue="survived",color="green")
plt.show()

# %%
sns.scatterplot(x="age",y="fare",data=df,size="sex")
plt.show()

# %%
sns.scatterplot(x="age",y="fare",data=df,hue="sex")
plt.show()

# %%
sns.scatterplot(x="age",y="fare",data=df,s=300)
plt.show()

# %%
sns.scatterplot(x="age",y="fare",hue="survived",data=df)
plt.show()

# %%
pip install plotly.io

# %%
# !pip install plotly

# %%
import plotly.express as px

# %%
import pandas as pd
import numpy as np
data={
    "Name":["a","b","c","d","e"],
    "Age":[20,34,40,50,60],
    "dept":["IT","HR","IT","HR","IT"]
    
}
df=pd.DataFrame(data)
df

# %%
x =df["pclass"]
y=df["fare"]
plt.bar(x,y)
plt.show()

# %%
df

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio
pio.renderers.default="notebook"
px.bar(df,x="pclass",y="fare")

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio
pio.renderers.default="notebook"
px.bar(df,x="sex",)

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio
pio.renderers.default="notebook"
px.bar(df,x="embarked")

# %% [markdown]
# # color meaning is grouping

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio
pio.renderers.default="notebook"
px.bar(df,x="pclass",y="fare",color="survived")

# %% [markdown]
# # title

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio
pio.renderers.default="notebook"
px.bar(df,x="pclass",y="fare",color="survived", title="barplot").update_layout(title_x=0.5)

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio
pio.renderers.default="notebook"
px.bar(df,x="pclass",y="fare",text_auto=True)

# %% [markdown]
# # hover=""

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio
pio.renderers.default="notebook"
px.bar(df,x="pclass",y="fare",hover_data="sex")

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio
pio.renderers.default="notebook"
px.bar(df,x="sex",y="age",orientation="h")

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio
pio.renderers.default="notebook"
px.bar(df,x="sex",y="age",barmode="group")

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio
pio.renderers.default="notebook"
px.bar(df,x="sex",y="age",barmode="stack")

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio
pio.renderers.default="notebook"
px.bar(df,x="survived",y="age",barmode="stack")

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio
pio.renderers.default="notebook"
px.bar(df,x="survived",y="age",barmode="group")

# %% [markdown]
# # For barmode, we need:
# # 1 categorical for x
# # 1 categorical for color
# # 1 numerical for y

# %% [markdown]
# # “Bar mode needs categories, not more numbers.”

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio
pio.renderers.default="notebook"
px.bar(df,x="survived",y="age",color="sex", title="barplot", barmode="group")

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio
pio.renderers.default="notebook"
px.bar(df,x="survived",y="age",color="sex", title="barplot", barmode="stack")

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio
pio.renderers.default="notebook"
px.bar(df,x="pclass",y="fare",color="survived", title="barplot", barmode="relative")

# %%
fig = px.bar(
    df,
    x="pclass",
    y="fare",
    color="survived",
    pattern_shape="survived",
    
)

fig.show()

# %%
fig = px.bar(
    df,
    x="pclass",
    y="fare",
    color="survived",
    pattern_shape_sequence=[".","x"]
    
)

fig.show()

# %%
print(df["survived"].unique())

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio
pio.renderers.default="notebook"
px.bar(df,x="survived",y="fare",color="sex", title="barplot", barmode="group",text_auto=True,width=800,height=600,hover_data=["age","sex"],color_discrete_map={"0":"green","1":"purple"})

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio

pio.renderers.default = "notebook"

df["survived"] = df["survived"].astype("category")

fig = px.bar(
    df,
    x="pclass",
    y="fare",
    color="survived",
    barmode="group",
    text_auto=True,
    width=800,
    height=600,
    hover_data=["age", "sex"],
    color_discrete_map={0: "green", 1: "purple"}
)

fig.show()

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio
pio.renderers.default="notebook"
px.scatter(df,x="age",y="fare",color="survived", title="barplot")

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio
pio.renderers.default="notebook"
px.scatter(df,x="age",y="fare",color="name", title="barplot")

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio
pio.renderers.default="notebook"
px.scatter_matrix(df, title="barplot")

# %% [markdown]
# # Bubble Plot

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio
pio.renderers.default="notebook"
px.scatter(df,x="age",y="fare",size="survived", title="Bubble Plot")

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio
pio.renderers.default="notebook"
px.scatter(df,x="age",y="fare",size="age", title="Bubble Plot")

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio
pio.renderers.default="notebook"
px.scatter(df,x="age",y="fare",color="survived",facet_row="sex" )

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio
pio.renderers.default="notebook"
px.scatter(df,x="age",y="fare",color="survived",facet_col="sex" )

# %% [markdown]
# # 3D PLOT

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio
pio.renderers.default="notebook"
px.scatter_3d(df,x="age",y="fare",z="pclass",color="survived",width=800,height=600 )

# %% [markdown]
# # PIE CHART

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio
pio.renderers.default="notebook"
fig=px.pie(df,names="survived",)
fig.show()

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio

pio.renderers.default = "notebook"

# Example: assuming df is your DataFrame with a column "survived"
fig = px.pie(df, names="survived")

# Update trace to show both percent and label
fig.update_traces(textinfo='percent+label')

fig.show()

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio
pio.renderers.default="notebook"
fig=px.pie(df,names="survived",values="age")
fig.show()

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio
pio.renderers.default="notebook"
fig=px.pie(df,names="survived")
fig.show()

# %%
,color_discrete_map={0:"pink",1:"purple"}

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio
pio.renderers.default="notebook"
fig=px.pie(df,names="survived",color_discrete_sequence=["yellow","blue"])
fig.show()

# %% [markdown]
# # Histogram

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio
pio.renderers.default="notebook"
px.histogram(df,x="age",nbins=20)

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio
pio.renderers.default="notebook"
px.histogram(df,x="age",nbins=5)

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio
pio.renderers.default="notebook"
px.histogram(df,x="age",nbins=5,color="sex")

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio
pio.renderers.default="notebook"
px.histogram(df,x="age",nbins=20,color="sex",y="fare",histfunc="sum")

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio
pio.renderers.default="notebook"
px.histogram(df,x="age",nbins=20,color="sex",y="fare",histfunc="avg")

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio
pio.renderers.default="notebook"
px.histogram(df,x="age",nbins=20,color="sex",y="fare",histfunc="count",text_auto=True)

# %% [markdown]
# # Unit 1

# %%
df

# %%
import pandas as pd
import numpy as np

pd.crosstab(df["pclass"],df["survived"])

# %%
import pandas as pd
import numpy as np

pd.crosstab(df["pclass"],df["sex"])

# %%
import pandas as pd
import numpy as np

pd.crosstab(df["pclass"],df["survived"],margins=True)

# %%
import pandas as pd
import numpy as np

pd.crosstab(df["pclass"],df["sex"],normalize=True)

# %% [markdown]
# # Line Graph

# %%
import pandas as pd
import numpy as ny
data={
    "Year":[2021,2022,2023,2021,2022,2023],
   
     "Dept":["IT","IT","IT","HR","HR","HR"],
    
    "Salary":[5000,5500,6000,4000,4200,4500]
    }
df=pd.DataFrame(data)
df

# %% [markdown]
# # Single Line Chart

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio
pio.renderers.default="notebook"
px.line(df[df["Dept"]=="IT"],x="Year",y="Salary",markers=True)

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio
pio.renderers.default="notebook"
px.line(df[df["Dept"]=="IT"],x="Year",y="Salary",markers=False)

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio
#pio.renderers.default="notebook"
px.line(df,x="Year",y="Salary",color="Dept")

# %%
case 1 add singel node

# %%
G.add_node(1)

# %%
case 2 multiple node

# %%
G.add_nodes_from([1,2,3])

# %%
case3 single edge

# %% [raw]
# G.add_edge[(1,2)]

# %%
case 4 multiple edge

# %% [raw]
# G.add_edges_from[(1,2),(2,3)]

# %% [markdown]
# # Networkx

# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
G=nx.Graph()
G.add_nodes_from([1,2,3,4])
G.add_edges_from([(1,2),(2,3),(3,4),(4,1)])
nx.draw(G)
plt.show()

# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
G=nx.Graph()
G.add_nodes_from([1,2,3,4])
G.add_edges_from([(1,2),(2,3),(3,4),(4,1)])
nx.draw(G,with_labels=True)
plt.show()

# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
G=nx.Graph()
G.add_nodes_from([1,2,3,4])
G.add_edges_from([(1,2),(2,3),(3,4),(4,1)])
nx.draw(G,with_labels=True,node_size=100)
plt.show()

# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
G=nx.Graph()
G.add_nodes_from([1,2,3,4])
G.add_edges_from([(1,2),(2,3),(3,4),(4,1)])
nx.draw(G,with_labels=True,node_size=1000)
plt.show()

# %% [markdown]
# # Color node_color="red"

# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
G=nx.Graph()
G.add_nodes_from([1,2,3,4])
G.add_edges_from([(1,2),(2,3),(3,4),(4,1)])
nx.draw(G,with_labels=True,node_size=1000,node_color="red")
plt.show()

# %%
# Digraph

# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
D=nx.DiGraph()
D.add_nodes_from([1,2,3,4])
D.add_edges_from([(1,2),(2,3),(3,4),(4,1)])
nx.draw(D)
plt.show()

# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
D=nx.DiGraph()
D.add_nodes_from([1,2,3,4])
D.add_edges_from([(1,2),(2,3),(3,4),(4,1)])
nx.draw(D,with_labels=True,node_size=1000,node_color="red")
plt.show()

# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
D=nx.DiGraph()
#D.add_nodes_from(["A","B","C","D"])
D.add_edges_from([(1,2),(2,3),(3,4),(4,1)])
nx.draw(D,with_labels=True,node_size=1000,node_color="red")
plt.show()

# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
D=nx.DiGraph()
#D.add_nodes_from(["A","B","C","D"])
D.add_edges_from([("A","B"),(2,3),(3,4),(4,1)])
nx.draw(D,with_labels=True,node_size=1000,node_color="red")
plt.show()

# %%
import pandas as pd
import numpy as np
data= {
    "emp_id":[101,102,103],
    "name":["A","B","C"]
}
df1=pd.DataFrame(data)
df1

# %%
import pandas as pd
import numpy as np
data= {
    "emp_id":[101,102,103],
    "dept":["IT","HR","IT"]
}
df2=pd.DataFrame(data)
df2

# %%
pd.concat([df1,df2])

# %%
pd.concat([df1,df2],ignore_index=True)

# %%
pd.concat([df1,df2],ignore_index=True,axis=0)

# %%
pd.concat([df1,df2],ignore_index=True,axis=1)

# %%
pd.concat([df1,df2],ignore_index=True,axis=1,join="inner")

# %%
pd.concat([df1,df2],ignore_index=True,axis=1,join="outer")

# %% [markdown]
# # Merge

# %%
import pandas as pd
import numpy as np
data= {
    "emp_id":[101,102,103],
    "name":["A","B","C"]
}
df1=pd.DataFrame(data)
df1

# %%
import pandas as pd
import numpy as np
data= {
    "emp_id":[101,102,104],
    "dept":["IT","HR","IT"]
}
df2=pd.DataFrame(data)
df2

# %%
pd.merge(df1,df2,on="emp_id",how="inner")# common

# %%
pd.merge(df1,df2,on="emp_id",how="outer")# all frame

# %%
pd.merge(df1,df2,on="emp_id",how="left")

# %%
pd.merge(df1,df2,on="emp_id",how="right")

# %% [markdown]
# # CH-3  Get dummies

# %%
import pandas as pd
import numpy as np
data={
    "Name":["A","B","C","D","E","F"],
    "Gender":["Male","Female","Male","Female","Male","Female"],
     "Dept":["IT","HR","Sales","IT","HR","Sales"],
    "Age":[20,22,24,26,28,30],
    "Salary":[3000,4000,5000,6000,7000,8000],
    }
df=pd.DataFrame(data)
df

# %%
pd.get_dummies(df,columns=["Gender","Dept"])

# %%
pd.get_dummies(df,columns=["Gender","Dept"],drop_first=True)

# %%
pd.get_dummies(df,drop_first=True)

# %%
pd.get_dummies(df,columns=["Gender","Dept"],drop_first=False)

# %%
pd.get_dummies(df,columns=["Gender","Dept"],drop_first=True)

# %%
df["bonus"]=np.where(df["Salary"]>5000,"good","bad")
df

# %% [raw]
# 10 mcq  8,9
# 6- writter code ------ 3,3------4,2   1----> ploty----bar,pie,histo,scatter,bubble   2----> dataframe ,dummies,np.where
# 9-program

# %% [raw]
# 1 mcq name, dept, salary
# 0a it 20
# 1 b hr 30
# df.iloc[0,"salary"] ---> error iloc

# %% [raw]
# 1  df create
# ii uniqueness
# iii drop va replce remove null

# %% [raw]
# 9

# %% [raw]
# outlier
# 1 find out quatiles
# 2 detect outliers
# 3 find IQR = q3-q1 upper lower
# 4 remove outliers
#
#
# replace nan
# croosstab,
# groupby more on it from pb or own

# %% [raw]
# df.gruopby["survived"]('female')sum()
# df.crosstab([df[survived],df[gender]]margins=True)

# %%
subset topic work on two colmun

# %%
df["bonus"]=df["salary"].apply(lambda x:x*10)

# %%
import networkx as nx
G=nx.DiGraph()
G.add_nodes_from(["a","b","c","d"])
G.add_edges_from([("a","b"),("b","c"),("c","d"),("d","a")])
nx.draw(G)

# %%
import networkx as nx
G=nx.DiGraph()
G.add_nodes_from([1,2,3,4,5])
G.add_edges_from([(1,1),(1,2),(1,5),(1,3),(2,1),(2,0),(0,2),(0,1),(0,3),(2,5),(2,4)])
nx.draw(G,node_color="pink",with_labels=True)

# %%
import networkx as nx
G=nx.DiGraph()
G.add_nodes_from([1,2,3,4])
G.add_edges_from([(3,1),(3,0),(3,2),(2,3),(2,1),(1,2),(2,4),(2,0),(0,2),(0,1),(0,4),(4,0),(4,1),(1,4)])
nx.draw(G,node_color="pink",edge_color="blue",with_labels=True)
